# %% [markdown]
# # Hypothesis
#
# There must be a direct effect on weather patters and agricultural production. Though this may seem like a fairly obvious factor, it will be interesting to see which crops are produced in higher amounts given certain weather conditions. My prediction is that certaom crop categrories will benifit and be produced in higher levels given certain weather factors: fruits and vegetables will be produced in a higher amount in years with high perciptiation and high temperatures. Nightshade crops like potato will be produced in greatest amount in years with high perciptiation and a lower average temperature. Grains will be produced in greater amount in years in years with high percipitation and a more moderate temperature. The location to study is Spain. The selection of Spain is somewhat arbitrary
#
# # Classifier
#
# I will be trying to understand and predict the

# %%
import pandas as pd

pd.read_csv('./data/spain_crops.csv')
# Out:
#       Domain Code                        Domain  Area Code (M49)   Area  \
# 0             QCL  Crops and livestock products              724  Spain
# 1             QCL  Crops and livestock products              724  Spain
# 2             QCL  Crops and livestock products              724  Spain
# 3             QCL  Crops and livestock products              724  Spain
# 4             QCL  Crops and livestock products              724  Spain
# ...           ...                           ...              ...    ...
# 22871         QCL  Crops and livestock products              724  Spain
# 22872         QCL  Crops and livestock products              724  Spain
# 22873         QCL  Crops and livestock products              724  Spain
# 22874         QCL  Crops and livestock products              724  Spain
# 22875         QCL  Crops and livestock products              724  Spain
#
#        Element Code         Element Item Code (CPC)                     Item  \
# ...

# %%
pd.read_csv('./data/spain_weather_more.csv')
# Out:
#           STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0     SPE00119792  ASTURIAS AVILES, SP   43.5667    -6.0442      127.0  1969
# 1     SPE00119792  ASTURIAS AVILES, SP   43.5667    -6.0442      127.0  1970
# 2     SPE00119792  ASTURIAS AVILES, SP   43.5667    -6.0442      127.0  1971
# 3     SPE00119792  ASTURIAS AVILES, SP   43.5667    -6.0442      127.0  1972
# 4     SPE00119792  ASTURIAS AVILES, SP   43.5667    -6.0442      127.0  1973
# ...           ...                  ...       ...        ...        ...   ...
# 6406  SPE00156603      ULLDEMOLINS, SP   41.3200     0.8856      687.0  2018
# 6407  SPE00156603      ULLDEMOLINS, SP   41.3200     0.8856      687.0  2020
# 6408  SPE00156603      ULLDEMOLINS, SP   41.3200     0.8856      687.0  2021
# 6409  SPE00156603      ULLDEMOLINS, SP   41.3200     0.8856      687.0  2022
# 6410  SPE00156603      ULLDEMOLINS, SP   41.3200     0.8856      687.0  2023
#
# ...

# %%
pd.read_csv('./data/carbon_emissions.csv')
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 48053     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 48054     Zimbabwe  2019      ZWE  15354606.0           NaN       0.473
# 48055     Zimbabwe  2020      ZWE  15669663.0           NaN       0.496
# 48056     Zimbabwe  2021      ZWE  15993525.0           NaN       0.531
# 48057     Zimbabwe  2022      ZWE  16320539.0           NaN       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...
